# %%
# html index viejo:
'''

{% extends "base.html" %}

{% block title %}Inicio{% endblock %}

{% block content %}
    <h1>Bienvenido a nuestra página de inicio</h1>
    <p>Este es el archivo desde la página creada.</p>
    <a href="#">Enlace con imagen de fondo</a>
{% endblock %}

'''

# %%
''' CSS solo barras:

body {

    background-color: yellowgreen;

}

#barra {

    margin:auto;
    width: 600px;
    list-style: none;
    border-bottom: 1px dotted #999;
    font-size: 2em;


}

#elem {
    float:left;
    margin-right: 20px;
}

a {
    text-decoration: none;
}

a:visited {
    color: rgb(1,20,29)
}


'''

# %%
'''CSS barras con las fotos pero encima los labels:

body {
    background-color: rgba(10, 1, 1, 0.196);
    margin: 0;
    font-family: Arial, sans-serif;
}

#barra {
    margin: auto;
    width: 100%;
    list-style: none;
    padding: 0;
    background-color: #333;
    display: flex;
    justify-content: center;
}

#barra li {
    margin: 0;
}

#barra li a {
    display: block;
    text-decoration: none;
    color: white;
    text-align: center;
    padding: 14px 20px;
    background-image: url('../imagenes/image.png'); /* Ruta de la imagen por defecto */
    background-size: cover; /* Ajusta la imagen al tamaño del enlace */
    width: 100px; /* Ajusta el tamaño según sea necesario */
    height: 100px; /* Ajusta el tamaño según sea necesario */
    transition: transform 0.3s ease, background-image 0.3s ease; /* Suaviza la transición */
}

#barra li a:visited {
    color: white; /* Color del texto después de visitar el enlace */
}

#barra li a:hover {
    background-image: url('../imagenes/image.png'); /* Ruta de la imagen cuando se pasa el ratón */
    transform: scale(1.2); /* Incrementa el tamaño al 120% */
}

# %%
from rembg import remove
from PIL import Image

def remove_background(input_image_path, output_image_path):
    # Cargar la imagen
    input_image = Image.open(input_image_path)
    
    # Eliminar el fondo
    output_image = remove(input_image)
    
    # Guardar la imagen resultante
    output_image.save(output_image_path)
    
# Ejemplo de uso
remove_background("static/imagenes/image.png", "static/imagenes/image_01.png")

# %%
from rembg import remove
from PIL import Image

input_path = "static/imagenes/image.png"
output_path = "static/imagenes/image_01.png"

inp = Image.open (input_path)
output = remove (inp)
output.save (output_path)

# %%
''' index viejo:

{% extends "base.html" %}

{% block title %}Inicio{% endblock %}

{% block content %}
    <header>
    </header>
    <div class="banner">
        <div class="list">
            <div class="item"><img src="{{ url_for('static', filename='imagenes/image.png') }}" alt=""></div>
            <div class="item"><img src="{{ url_for('static', filename='imagenes/image_2.png') }}" alt=""></div>
            <div class="item"><img src="{{ url_for('static', filename='imagenes/image_3.png') }}" alt=""></div>
        </div>
    </div>
    <h1>Bienvenido a nuestra página de inicio</h1>
    <p>Este es el archivo desde la página creada.</p>
    <a href="#">Enlace con imagen de fondo</a>
    <footer>
    </footer>
{% endblock %}

'''

# %%
'''css:

body {
    background-color: rgb(0, 0, 0);
}

#barra {
    margin: auto;
    width: 600px;
    list-style: none;
    border-bottom: 1px dotted #999;
    font-size: 2em;
}

#elem {
    float: left;
    margin-right: 20px;
}

a {
    text-decoration: none;
    color: white;
    display: block;
    padding: 10px;
}

a:visited {
    color: rgb(251, 251, 251);
}

.list {
    display: flex; /* Utiliza Flexbox para alinear los elementos en fila */
    justify-content: space-around; /* Espacia los elementos uniformemente */
    align-items: center; /* Alinea los elementos verticalmente al centro */
}

.item {
    flex: 1; /* Permite que los elementos se distribuyan uniformemente */
    margin: 10px; /* Añade margen alrededor de cada elemento */
}

.list:hover .item {
    filter: grayscale(1) blur(10px);
}

.list:hover .item:hover {
    filter: none;
}

'''

# %%
/* index.css */

body {
    background-color: rgb(0, 0, 0);
    margin: 0;
    padding: 0;
}

#barra {
    margin: auto;
    width: 100%;
    list-style: none;
    border-bottom: 1px dotted #791818;
    font-size: 2em;
    background-color: #8e1010; /* Fondo para la barra de navegación */
}

#barra li {
    float: left;
    margin-right: 20px;
}

a {
    text-decoration: none;
    color: white;
    display: block;
    padding: 10px;
}

a:visited {
    color: rgb(251, 251, 251);
}

.banner {
    width: 100%; 
    display: flex; 
    justify-content: space-between;
    padding: 20px;
    box-sizing: border-box; 
}

.list {
    display: flex;
    width: 100%;
}

.item {
    position: relative;
    flex: 1;
    margin: 0 5px;
}

.item img {
    width: 100%;
    height: auto;
    display: block;
}

.label {
    position: absolute;
    top: 0;
    left: 50%;
    transform: translateX(-50%);
    color: white;
    font-size: 1.5em;
    padding: 5px;
    background: rgba(0, 0, 0, 0.5);
    text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.7);
    text-align: center;
    pointer-events: none;
}

.list:hover .item {
    filter: grayscale(1) blur(10px);
}

.list:hover .item:hover {
    filter: none;
}

# %%
/* index.css */

/* General body styles */
body {
    background-color: rgb(0, 0, 0);
    margin: 0;
    padding: 0;
    color: white; /* Color del texto por defecto */
    font-family: Arial, sans-serif; /* Fuente predeterminada */
}

/* Barra de navegación */
#barra {
    margin: 0 auto; /* Asegura que la barra esté centrada horizontalmente */
    width: 100%;
    list-style: none;
    border-bottom: 1px dotted #791818;
    font-size: 2em;
    background-color: #8e1010; /* Fondo para la barra de navegación */
    padding: 10px 0; /* Espaciado adicional para la barra de navegación */
    box-sizing: border-box; /* Incluye padding en el ancho total */
}

#barra li {
    float: left;
    margin-right: 20px;
}

a {
    text-decoration: none;
    color: white;
    display: block;
    padding: 10px;
}

a:visited {
    color: rgb(251, 251, 251);
}

/* Estilos para el banner y las imágenes */
.banner {
    width: 100%;
    display: flex;
    justify-content: space-between;
    padding: 20px;
    box-sizing: border-box;
}

.list {
    display: flex;
    width: 100%;
}

.item {
    position: relative;
    flex: 1;
    margin: 0 5px;
}

.item img {
    width: 100%;
    height: auto;
    display: block;
}

.label {
    position: absolute;
    top: 0;
    left: 50%;
    transform: translateX(-50%);
    color: white;
    font-size: 1.5em;
    padding: 5px;
    background: rgba(0, 0, 0, 0.5);
    text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.7);
    text-align: center;
    pointer-events: none;
}

/* Estilos para la sección de contenido principal */
section {
    padding: 20px;
    background-color: #ecb4b41e; /* Fondo claro para que el texto sea legible */
    color: rgb(255, 255, 255); /* Color del texto en la sección */
    border-radius: 8px;
    margin: 40px auto; /* Añadido margen superior para separar el contenido del encabezado */
    max-width: 800px; /* Máximo ancho para el contenido */
    box-sizing: border-box; /* Incluye padding en el ancho total */
}

/* Estilos para encabezados */
h1 {
    font-size: 2em;
    color: #eae4e4; /* Color del encabezado más oscuro para contraste */
}

/* Estilos para párrafos */
p {
    font-size: 1em;
    line-height: 1.6;
}

/* Estilos para listas */
ul {
    list-style-type: none; /* Quita los puntos de la lista */
    padding: 0; /* Quita el padding predeterminado */
    margin: 0; /* Quita el margen predeterminado */
}

ul li {
    margin-bottom: 10px; /* Espacio entre los elementos de la lista */
    padding-left: 20px; /* Indenta los elementos de la lista */
    position: relative; /* Necesario para el posicionamiento del símbolo */
}

ul li:first-child {
    padding-left: 0; /* Sin indentación para el primer elemento */
}

ul li::before {
    color: #007bff; /* Color de la viñeta */
    position: absolute;
    left: 0;
    font-size: 1.2em;
    line-height: 1.2em;
}

/* Estilos para enlaces */
a {
    color: white;
    text-decoration: none;
}

a:visited {
    color: rgb(251, 251, 251);
}

/* Efectos de hover para las imágenes */
.list:hover .item {
    filter: grayscale(1) blur(10px);
}

.list:hover .item:hover {
    filter: none;
}

# %%
import os
import pickle
path_base = os.path.join(os.getcwd(), 'TC_WEB')
model_path = os.path.join(path_base, 'ad_model.pkl')
model = pickle.load(open(model_path, 'rb'))

#C:\cosas\Proyecto_TC_WEB\TC_WEB
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       3 path_base = os.path.join(os.getcwd(), 'TC_WEB')
#       4 model_path = os.path.join(path_base, 'ad_model.pkl')
# ----> 5 model = pickle.load(open(model_path, 'rb'))
#
# File c:\Users\pobla\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\cosas\\Proyecto_TC_WEB\\TC_WEB\\TC_WEB\\ad_model.pkl'

# %%
path_base = 'C:\\cosas\\Proyecto_TC_WEB\\TC_WEB\\'
model = pickle.load(open(path_base + 'ad_model.pkl', 'rb'))

# %%
import os

path_base = 'C:\\cosas\\Proyecto_TC_WEB\\TC_WEB\\'
file_path = os.path.join(path_base, 'ad_model.pkl')

if os.path.exists(file_path):
    print("El archivo existe.")
else:
    print("El archivo NO existe.")
# Out:
# El archivo existe.

# %%
import pandas as pd

df_1= pd.read_csv("./data/wines_dataset.csv", sep = "|")
df = pd.read_csv ('data/wines_expandido.csv')

# %%
df_1.head ()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            8.5              0.21         0.26            9.25      0.034
# 1            8.3              0.16         0.37            7.90      0.025
# 2            6.8              0.18         0.38            1.40      0.038
# 3            6.1              0.26         0.25            2.90      0.047
# 4            7.5              0.63         0.27            2.00      0.083
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 73.0                 142.0  0.99450  3.05       0.37
# 1                 38.0                 107.0  0.99306  2.93       0.37
# 2                 35.0                 111.0  0.99180  3.32       0.59
# 3                289.0                 440.0  0.99314  3.44       0.64
# 4                 17.0                  91.0  0.99616  3.26       0.58
#
#    alcohol  quality  class
# 0     11.4        6  white
# 1     11.9        6  white
# ...

# %%
df_1.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  class                 6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7497 entries, 0 to 7496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         7497 non-null   float64
#  1   volatile acidity      7497 non-null   float64
#  2   citric acid           7497 non-null   float64
#  3   residual sugar        7497 non-null   float64
#  4   chlorides             7497 non-null   float64
#  5   free sulfur dioxide   7497 non-null   float64
#  6   total sulfur dioxide  7497 non-null   float64
#  7   density               7497 non-null   float64
#  8   pH                    7497 non-null   float64
#  9   sulphates             7497 non-null   float64
#  10  alcohol               7497 non-null   float64
#  11  quality               7497 non-null   float64
#  12  class                 7497 non-null   object
# dtypes: float64(12), object(1)
# memory usage: 761.5+ KB

# %%
df['quality'] =df ['quality'].astype('Int64')

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7497 entries, 0 to 7496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         7497 non-null   float64
#  1   volatile acidity      7497 non-null   float64
#  2   citric acid           7497 non-null   float64
#  3   residual sugar        7497 non-null   float64
#  4   chlorides             7497 non-null   float64
#  5   free sulfur dioxide   7497 non-null   float64
#  6   total sulfur dioxide  7497 non-null   float64
#  7   density               7497 non-null   float64
#  8   pH                    7497 non-null   float64
#  9   sulphates             7497 non-null   float64
#  10  alcohol               7497 non-null   float64
#  11  quality               7497 non-null   Int64
#  12  class                 7497 non-null   object
# dtypes: Int64(1), float64(11), object(1)
# memory usage: 768.9+ KB

# %%
df.to_csv('vinos_new.csv', index=False)

# %%
df_new = pd.read_csv ('vinos_new.csv')

# %%
df_new.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7497 entries, 0 to 7496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         7497 non-null   float64
#  1   volatile acidity      7497 non-null   float64
#  2   citric acid           7497 non-null   float64
#  3   residual sugar        7497 non-null   float64
#  4   chlorides             7497 non-null   float64
#  5   free sulfur dioxide   7497 non-null   float64
#  6   total sulfur dioxide  7497 non-null   float64
#  7   density               7497 non-null   float64
#  8   pH                    7497 non-null   float64
#  9   sulphates             7497 non-null   float64
#  10  alcohol               7497 non-null   float64
#  11  quality               7497 non-null   int64
#  12  class                 7497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 761.5+ KB

# %%
@app.route('/retrain', methods=['GET', 'POST'])
def retrain():
    if request.method == 'GET':
        return render_template('retrain.html')

    if request.method == 'POST':
        if os.path.exists("./data/wines_expandido.csv"):
            data = pd.read_csv("./data/wines_expandido.csv")
            X_train, X_test, y_train, y_test = train_test_split(data.drop(columns=['quality']),
                                                                data['quality'],
                                                                test_size=0.20,
                                                                random_state=42)
            X_train["class"] = (X_train["class"] == "white").astype(int)
            X_test["class"] = (X_test["class"] == "white").astype(int)
            features_to_transform = ["chlorides", "free sulfur dioxide", "total sulfur dioxide"]
            for col in features_to_transform:
                desplaza = 0
                if X_train[col].min() <= 0:
                    desplaza = int(abs(X_train[col].min())) + 1
                X_train[col] = np.log(X_train[col] + desplaza)
                X_test[col] = np.log(X_test[col] + desplaza)
            features_clf = ['class', 'volatile acidity', 'citric acid', 'chlorides', 'free sulfur dioxide', 
                            'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol']
            lr_clf = LogisticRegression(max_iter=1000, class_weight="balanced")
            param_grid = {
                'max_iter': [1000, 10000],
                'class_weight': ['balanced', None],
            }
            lr_grid = GridSearchCV(lr_clf,
                                   param_grid=param_grid,
                                   cv=5,
                                   scoring="balanced_accuracy")
            lr_grid.fit(X_train[features_clf], y_train)
            y_pred = lr_grid.best_estimator_.predict(X_test[features_clf])
            class_report = classification_report(y_test, y_pred, output_dict=True)

            # Generar matriz de confusión y guardarla como imagen
            fig, ax = plt.subplots()
            ConfusionMatrixDisplay.from_predictions(y_test, y_pred, normalize="true", ax=ax)
            buf = io.BytesIO()
            plt.savefig(buf, format='png')
            buf.seek(0)
            img_base64 = base64.b64encode(buf.getvalue()).decode('utf-8')
            plt.close(fig)

            with open('ad_model.pkl', 'wb') as file:
                pickle.dump(lr_grid.best_estimator_, file)

            return render_template('retrain_result.html', class_report=class_report, img_data=img_base64)
        else:
            return render_template('retrain_result.html', error="New data for retrain NOT FOUND. Nothing done!")

# %%
{% extends "base.html" %}

{% block title %}Inicio{% endblock %}

{% block content %}
    <ul id="barra">
        <li><a href="{{ url_for('data') }}">Data</a></li>
        <li><a href="{{ url_for('predicciones') }}">Predicciones</a></li>
        <li><a href="{{ url_for('retrain') }}">Retrain</a></li>
    </ul>
    <head>
        <meta charset="UTF-8">
        <meta name="viewport" content="width=device-width, initial-scale=1.0">
        <title>Resultado del Retrain</title>
    </head>
    <body>
        <h1>Resultado del Retrain del Modelo</h1>
        {% if error %}
            <p>{{ error }}</p>
        {% else %}
            <h2>Classification Report:</h2>
            <pre>{{ class_report }}</pre>
            <h2>Matriz de Confusión:</h2>
            <img src="data:image/png;base64,{{ img_data }}" alt="Matriz de Confusión">
        {% endif %}
        <a href="/retrain">Volver a Retrain</a>
    </body>
{% endblock %}
